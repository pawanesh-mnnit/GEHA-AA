# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
InAViT = [(3.19, 14.4), (4.64, 23.4), (10.41, 41.0), (26.86, 83.3), (32.24, 157.2), (34.58, 194.1), (39.89, 238.7)]
geha = [(4.19, 13.4), (6.64, 23.4), (12.41, 41.0), (26.86, 83.3), (32.24, 157.2), (34.58, 194.1), (39.89, 238.7)]

fig = plt.figure(figsize=(7.02,3.54), dpi=600)
ax = fig.add_subplot(111)
layers = [1,2,4,8,12,16,20]

in_x = [yt for xt,yt in InAViT]
in_y = [xt for xt,yt in InAViT]
geha_x = [yt for xt,yt in geha]
geha_y = [xt for xt,yt in geha]

plt.plot(in_x, in_y, "b--", label="InAViT")
plt.plot(geha_x, geha_y, "r--", label="GEHA-AA")
plt.legend(loc="upper left")
plt.xlabel('Number of Parameters', fontsize=15)
plt.ylabel('Action Mean Recall @5', fontsize=15)
for yt, xt in mf:
    ax.scatter(xt, yt, color='blue', marker='o')
    
for i in range(len(InAViT)):
    plt.annotate(layers[i], (InAViT[i][1],InAViT[i][0]), xytext=(5, 5), textcoords="offset pixels")

for yt, xt in geha:
    ax.scatter(xt, yt, color='red', marker='*')
for i in range(len(geha)):
    plt.annotate(layers[i], (geha[i][1],geha[i][0]), xytext=(5, 5), textcoords="offset pixels")

plt.show()

# %%
InAViT = [(20.82, 75.2), (26.17, 143.9), (28.84, 182.8), (32.50, 222.8) ]
geha = [(26.86, 83.3), (32.24, 157.2), (34.58, 194.1), (39.89, 238.7)]

# %%
import numpy as np
params = []
perfs = []
for i in range(4):
    perfs.append(geha[i][0] - InAViT[i][0])
    params.append(geha[i][1] - InAViT[i][1])

print(np.mean(params))
print(np.mean(perfs))
# Out:
# 12.149999999999984
# 6.31
